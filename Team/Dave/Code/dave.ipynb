# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
cities = ['Chicago', 'Nashville', 'Denver',
          'Seattle', 'Honolulu', 'Miami', 'Omaha',
         'Houston', 'Phoenix', 'Albuquerque']

# %%
high = []
low = []
cur = []
feel = []
humid = []
pressure = []

# %%
url_Chic = 'https://weather.com/weather/today/l/e0abde3003a88dedecad92fedc96375000c16843287a51dbf2cd92f062217180'
url_Nash = 'https://weather.com/weather/today/l/c497a8fe783a21075e4be0fe8e3851415b88cb2e30a6fa184550e22a7ae728c6'
url_Denv = 'https://weather.com/weather/today/l/675c2b6342b3512ea4f15bc9070663be6e36cc4bf61056076c500098c8eb3bbe'
url_Seat = 'https://weather.com/weather/today/l/ced0de18c1d771856e6012f3abf0a952cfe22952e72e516e6e098d54ca737114'
url_Hono = 'https://weather.com/weather/today/l/263f49e812cfbd2c5812f4c3f3dec5eb89d625bb80fab3d024ed4d3a10220f32'
url_Miam = 'https://weather.com/weather/today/l/3881cd527264bc7c99b6b541473c0085e75aa026b6bd99658c56ad9bb55bd96e'
url_Omah = 'https://weather.com/weather/today/l/249cf41186d4f776ce51abe6b22bbf8aa2c285e24387cbab91e6aaa518bfbc3c'
url_Hous = 'https://weather.com/weather/today/l/110a124808308e4fc03ee2b75754a7e06e9334b6d23d6fa317f1bb84b5f8a65e'
url_Phoe = 'https://weather.com/weather/today/l/729d869b5da7e1b89835d0de7940cda8b0b2e0dafda4ef6f742b558409755f66'
url_Albu = 'https://weather.com/weather/today/l/cdad20b8f7657de1012528aeda289407445c7be167e14dd56a66b0cd3716ff03'

# %%
urls = [url_Chic, url_Nash, url_Denv, url_Seat, url_Hono, url_Miam, url_Omah, url_Hous, url_Phoe, url_Albu]

# %%
response = requests.get(url_Nash)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Whole thing
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-connection-speed="4g" data-device-class="desktop" dir="ltr" itemscope="" itemtype="http://schema.org/Organization" lang="en-US" prefix="fb: http://ogp.me/ns/fb# og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product#">
#  <head itemscope="" itemtype="http://schema.org/WebSite">
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0, viewport-fit=cover" name="viewport"/>
#   <script charset="UTF-8">
# ...

# %%
# bit i want
x = soup.find('div', class_='today_nowcard-section')
print(x.prettify())
# Out:
# <div class="today_nowcard-section today_nowcard-condition">
#  <div class="condition-icon wx-weather-icon vector">
#   <icon class="icon icon-svg icon-svg-light icon-mostly-cloudy icon-28" classname="icon icon-svg icon-svg-light icon-mostly-cloudy icon-28">
#    <svg class="svg-mostly-cloudy" viewbox="0 0 230 200" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#     <defs>
#      <mask id="mostly-cloudy-mask">
#       <rect fill="#FFF" height="100%" width="100%">
#       </rect>
#       <use stroke="#000" stroke-width="9" transform="translate(-34.945 -34.945) scale(1.8392)" xlink:href="#svg-symbol-cloud">
#       </use>
#      </mask>
#     </defs>
#     <use class="svg-sun" mask="url(#mostly-cloudy-mask)" transform="matrix(.56 0 0 .56 11.2 16.8)" xlink:href="#svg-symbol-sun">
#     </use>
#     <use class="svg-cloud" transform="matrix(1.02 0 0 1.02 10 34)" xlink:href="#svg-symbol-cloud-junior">
#     </use>
# ...

# %%
temp = x.find('', class_='')
print(y)

# %%
feel = x.find('', class_='')
print(y)

# %%
high = x.find('', class_='')
print(y)

# %%
low = x.find('', class_='')
print(y)

# %%
pressure = x.find('', class_='')
print(y)

# %%
 = x.find('', class_='')
print(y)

# %%
# <div class="today_nowcard-section today_nowcard-condition">

# %%
<span data-testid="TemperatureValue" class="_-_-components-src-organism-CurrentConditions-CurrentConditions--tempValue--MHmYY">75°</span>

# %%
<div class="_-_-components-src-organism-CurrentConditions-CurrentConditions--primary--2DOqs"><span data-testid="TemperatureValue" class="_-_-components-src-organism-CurrentConditions-CurrentConditions--tempValue--MHmYY">75°</span><div data-testid="wxPhrase" class="_-_-components-src-organism-CurrentConditions-CurrentConditions--phraseValue--mZC_p">Mostly Cloudy</div></div>

# %%
for url in urls:
    print(url)
# Out:
# https://weather.com/weather/today/l/e0abde3003a88dedecad92fedc96375000c16843287a51dbf2cd92f062217180
# https://weather.com/weather/today/l/c497a8fe783a21075e4be0fe8e3851415b88cb2e30a6fa184550e22a7ae728c6
# https://weather.com/weather/today/l/675c2b6342b3512ea4f15bc9070663be6e36cc4bf61056076c500098c8eb3bbe
# https://weather.com/weather/today/l/ced0de18c1d771856e6012f3abf0a952cfe22952e72e516e6e098d54ca737114
# https://weather.com/weather/today/l/263f49e812cfbd2c5812f4c3f3dec5eb89d625bb80fab3d024ed4d3a10220f32
# https://weather.com/weather/today/l/3881cd527264bc7c99b6b541473c0085e75aa026b6bd99658c56ad9bb55bd96e
# https://weather.com/weather/today/l/249cf41186d4f776ce51abe6b22bbf8aa2c285e24387cbab91e6aaa518bfbc3c
# https://weather.com/weather/today/l/110a124808308e4fc03ee2b75754a7e06e9334b6d23d6fa317f1bb84b5f8a65e
# https://weather.com/weather/today/l/729d869b5da7e1b89835d0de7940cda8b0b2e0dafda4ef6f742b558409755f66
# ...
