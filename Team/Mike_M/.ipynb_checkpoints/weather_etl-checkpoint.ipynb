# %%
import requests
import pandas as pd
from config import api_key
import json
from pprint import pprint
import requests
import datetime as datetime
import time

# %%
# Save config information.
# url = f"http://api.openweathermap.org/data/2.5/weather?"
url = f"http://api.openweathermap.org/data/2.5/group?id=4887398,4644585,4463523,5809844,5856195,4164138,5074472,4699066,5308655,5454711&units=imperial&appid={api_key}&q="


response = requests.get(url)
cities = response.json()
pprint(cities)
# Out:
# {'cnt': 10,
#  'list': [{'clouds': {'all': 75},
#            'coord': {'lat': 41.85, 'lon': -87.65},
#            'dt': 1590711355,
#            'id': 4887398,
#            'main': {'feels_like': 67.26,
#                     'humidity': 64,
#                     'pressure': 1009,
#                     'temp': 72.09,
#                     'temp_max': 77,
#                     'temp_min': 68},
#            'name': 'Chicago',
#            'sys': {'country': 'US',
#                    'sunrise': 1590661201,
#                    'sunset': 1590714974,
#                    'timezone': -18000},
#            'visibility': 16093,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 330, 'speed': 13.87}},
#           {'clouds': {'all': 20},
#            'coord': {'lat': 36.17, 'lon': -86.78},
#            'dt': 1590711343,
#            'id': 4644585,
#            'main': {'feels_like': 75.81,
#                     'humidity': 73,
#                     'pressure': 1013,
#                     'temp': 73.47,
#                     'temp_max': 75.99,
#                     'temp_min': 71.01},
#            'name': 'Nashville',
#            'sys': {'country': 'US',
#                    'sunrise': 1590661968,
#                    'sunset': 1590713789,
#                    'timezone': -18000},
#            'visibility': 16093,
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 240, 'speed': 4.7}},
#           {'clouds': {'all': 1},
#            'coord': {'lat': 35.53, 'lon': -81.03},
#            'dt': 1590711336,
#            'id': 4463523,
#            'main': {'feels_like': 88.07,
#                     'humidity': 100,
#                     'pressure': 1017,
#                     'temp': 78.19,
#                     'temp_max': 80.01,
#                     'temp_min': 75.99},
#            'name': 'Denver',
#            'sys': {'country': 'US',
#                    'sunrise': 1590660688,
#                    'sunset': 1590712309,
#                    'timezone': -14400},
#            'visibility': 16093,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 194, 'speed': 4.32}},
#           {'clouds': {'all': 1},
#            'coord': {'lat': 47.61, 'lon': -122.33},
#            'dt': 1590711382,
#            'id': 5809844,
#            'main': {'feels_like': 69.71,
#                     'humidity': 33,
#                     'pressure': 1014,
#                     'temp': 76.6,
#                     'temp_max': 80.6,
#                     'temp_min': 73},
#            'name': 'Seattle',
#            'sys': {'country': 'US',
#                    'sunrise': 1590668291,
#                    'sunset': 1590724532,
#                    'timezone': -25200},
#            'visibility': 16093,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 290, 'speed': 10.29}},
#           {'clouds': {'all': 40},
#            'coord': {'lat': 21.31, 'lon': -157.86},
#            'dt': 1590711382,
#            'id': 5856195,
#            'main': {'feels_like': 76.26,
#                     'humidity': 45,
#                     'pressure': 1020,
#                     'temp': 82.45,
#                     'temp_max': 87.8,
#                     'temp_min': 77},
#            'name': 'Honolulu',
#            'sys': {'country': 'US',
#                    'sunrise': 1590680974,
#                    'sunset': 1590728905,
#                    'timezone': -36000},
#            'visibility': 16093,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 50, 'speed': 16.11}},
#           {'clouds': {'all': 75},
#            'coord': {'lat': 25.77, 'lon': -80.19},
#            'dt': 1590711328,
#            'id': 4164138,
#            'main': {'feels_like': 84.9,
#                     'humidity': 78,
#                     'pressure': 1017,
#                     'temp': 82.44,
#                     'temp_max': 82.99,
#                     'temp_min': 82},
#            'name': 'Miami',
#            'sys': {'country': 'US',
#                    'sunrise': 1590661814,
#                    'sunset': 1590710780,
#                    'timezone': -14400},
#            'visibility': 16093,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04n',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 100, 'speed': 13.87}},
#           {'clouds': {'all': 75},
#            'coord': {'lat': 41.26, 'lon': -95.94},
#            'dt': 1590711362,
#            'id': 5074472,
#            'main': {'feels_like': 64.47,
#                     'humidity': 30,
#                     'pressure': 1016,
#                     'temp': 77.65,
#                     'temp_max': 80.6,
#                     'temp_min': 75},
#            'name': 'Omaha',
#            'sys': {'country': 'US',
#                    'sunrise': 1590663300,
#                    'sunset': 1590716854,
#                    'timezone': -18000},
#            'visibility': 16093,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 350, 'speed': 20.8}},
#           {'clouds': {'all': 37},
#            'coord': {'lat': 29.76, 'lon': -95.36},
#            'dt': 1590711349,
#            'id': 4699066,
#            'main': {'feels_like': 87.76,
#                     'humidity': 61,
#                     'pressure': 1012,
#                     'temp': 82.42,
#                     'temp_max': 82.99,
#                     'temp_min': 82},
#            'name': 'Houston',
#            'sys': {'country': 'US',
#                    'sunrise': 1590664948,
#                    'sunset': 1590714928,
#                    'timezone': -18000},
#            'weather': [{'description': 'light rain',
#                         'icon': '10d',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 180, 'speed': 1.99}},
#           {'clouds': {'all': 20},
#            'coord': {'lat': 33.45, 'lon': -112.07},
#            'dt': 1590711375,
#            'id': 5308655,
#            'main': {'feels_like': 95.41,
#                     'humidity': 6,
#                     'pressure': 1008,
#                     'temp': 108.1,
#                     'temp_max': 109.99,
#                     'temp_min': 106},
#            'name': 'Phoenix',
#            'sys': {'country': 'US',
#                    'sunrise': 1590668446,
#                    'sunset': 1590719452,
#                    'timezone': -25200},
#            'visibility': 16093,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02d',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 300, 'speed': 14.99}},
#           {'clouds': {'all': 75},
#            'coord': {'lat': 35.08, 'lon': -106.65},
#            'dt': 1590711376,
#            'id': 5454711,
#            'main': {'feels_like': 80.19,
#                     'humidity': 14,
#                     'pressure': 1020,
#                     'temp': 87.03,
#                     'temp_max': 90,
#                     'temp_min': 82.99},
#            'name': 'Albuquerque',
#            'sys': {'country': 'US',
#                    'sunrise': 1590666904,
#                    'sunset': 1590718392,
#                    'timezone': -21600},
#            'visibility': 16093,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 110, 'speed': 5.82}}]}

# %%
# set up lists to hold reponse info

city_name = []
date = []
high = []
low = []
current = []
feels_like = []
humidity = []
pressure = []



dashes = "---------------------------------"



print(dashes)
print("Retireving Data")
print(dashes)

# Loop through the list of cities and perform a request for data on each

#     response = requests.get(url + city).json()
counter = 0
for counter in range(10):


#     response = requests.get(url + city).json()
    city_name.append(cities['list'][counter]['name'])
    date.append(cities['list'][counter]['dt'])
    high.append(cities['list'][counter]['main']['temp_max'])
    low.append(cities['list'][counter]['main']['temp_min'])
    current.append(cities['list'][counter]['main']['temp'])
    feels_like.append(cities['list'][counter]['main']['feels_like'])
    humidity.append(cities['list'][counter]['main']['humidity'])
    pressure.append(cities['list'][counter]['main']['pressure'])
    counter += 1

        
print(dashes)
print("Data Retrieved")
print
# Out:
# ---------------------------------
# Retireving Data
# ---------------------------------
# ---------------------------------
# Data Retrieved
# <function print>

# %%
# create a data frame from cities, lat, and temp
cities_dict = {
    "City": city_name,
    "Date": datetime.datetime.today(),
    "Daily High (F)": high,
    "Daily Low (F)": low,
    "Current Temp (F)": current,
    "Feels Like": feels_like,
    "Humidity (%)": humidity,
    "Pressure (mb)": pressure,
}
cities_df = pd.DataFrame(cities_dict)
cities_df.to_csv("api.csv")
cities_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8c74ff082cbc> in <module>
#       2 cities_dict = {
#       3     "City": city_name,
# ----> 4     "Date": datetime.datetime.today(),
#       5     "Daily High (F)": high,
#       6     "Daily Low (F)": low,
#
# NameError: name 'datetime' is not defined

# %%
# list = cities["list"]
# city_data = list["main"]
# name = city_data[0]["name"]
# daily_high = city_data[0]["temp_max"]
# daily_low= city_data[0]["temp_min"]
# current_temp = city_data[0]["temp"]
# humidity = city_data[0]["humidity"]
# barometer = city_data[0]["pressure"]
# city_date = list["dt"]


# cities = ['Chicago', 'Nashville', 'Denver',
#           'Seattle', 'Honolulu', 'Miami', 'Omaha',
#          'Houston', 'Phoenix', 'Albuquerque']
